# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss,classification_report
from sklearn.model_selection import StratifiedKFold
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from xgboost import plot_importance as xgb_importance
from lightgbm import plot_importance as lgb_importance
# Out:
# c:\Users\Abdramane Aly Diallo\anaconda3\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv('test.csv')

X = train.drop("Activity", axis=1)
Y = train.Activity

# %%
train.head()
# Out:
#    Activity        D1        D2    D3   D4        D5        D6        D7  \
# 0         1  0.000000  0.497009  0.10  0.0  0.132956  0.678031  0.273166
# 1         1  0.366667  0.606291  0.05  0.0  0.111209  0.803455  0.106105
# 2         1  0.033300  0.480124  0.00  0.0  0.209791  0.610350  0.356453
# 3         1  0.000000  0.538825  0.00  0.5  0.196344  0.724230  0.235606
# 4         0  0.100000  0.517794  0.00  0.0  0.494734  0.781422  0.154361
#
#          D8        D9  ...  D1767  D1768  D1769  D1770  D1771  D1772  D1773  \
# 0  0.585445  0.743663  ...      0      0      0      0      0      0      0
# 1  0.411754  0.836582  ...      1      1      1      1      0      1      0
# 2  0.517720  0.679051  ...      0      0      0      0      0      0      0
# 3  0.288764  0.805110  ...      0      0      0      0      0      0      0
# 4  0.303809  0.812646  ...      0      0      0      0      0      0      0
#
#    D1774  D1775  D1776
# 0      0      0      0
# 1      0      1      0
# 2      0      0      0
# 3      0      0      0
# 4      0      0      0
#
# [5 rows x 1777 columns]

# %% [markdown]
# ## EDA

# %%
X.isnull().sum().sum()
# Out:
# 0

# %%
sns.countplot(Y)
plt.show()

# %%
from collections import Counter

# %%
s = Counter([len(X[col].unique()) for col in X.columns])
count_cols_unique = sorted(list(set([len(X[col].unique()) for col in X.columns])))
d ={your_key: s[your_key] for your_key in count_cols_unique[:10] }
d
# Out:
# {2: 835, 3: 59, 4: 87, 5: 113, 6: 84, 7: 76, 8: 59, 9: 44, 10: 44, 11: 45}

# %% [markdown]
# Il y a beaucoup de colonnes à valeurs binaires. Ceci pourrait être un problème de feature engineering

# %%
non_binaries = [col for col in X.columns if len(X[col].unique())>2]
binaries = [col for col in X.columns if not col in non_binaries]

# %%
print(f'Il y a {len(non_binaries)} colonnes non binaires')
print(f'Il y a {len(binaries)} colonnes binaires')
# Out:
# Il y a 941 colonnes non binaires
# Il y a 835 colonnes binaires

# %%
train[non_binaries].describe()
# Out:
#                 D1           D2           D3           D4           D5  \
# count  3751.000000  3751.000000  3751.000000  3751.000000  3751.000000
# mean      0.076948     0.592436     0.068142     0.038990     0.212112
# std       0.079989     0.105860     0.078414     0.115885     0.102592
# min       0.000000     0.282128     0.000000     0.000000     0.002630
# 25%       0.033300     0.517811     0.000000     0.000000     0.138118
# 50%       0.066700     0.585989     0.050000     0.000000     0.190926
# 75%       0.100000     0.668395     0.100000     0.000000     0.261726
# max       1.000000     0.964381     0.950000     1.000000     1.000000
#
#                 D6           D7           D8           D9          D10  ...  \
# count  3751.000000  3751.000000  3751.000000  3751.000000  3751.000000  ...
# mean      0.686653     0.274713     0.455133     0.749517     0.270411  ...
# std       0.078702     0.090017     0.162731     0.071702     0.096128  ...
# min       0.137873     0.006130     0.000000     0.275590     0.003040  ...
# 25%       0.625627     0.207374     0.378062     0.707339     0.194357  ...
# 50%       0.674037     0.277845     0.499942     0.738961     0.284316  ...
# 75%       0.740663     0.335816     0.569962     0.788177     0.344626  ...
# max       0.994735     0.790831     0.989870     1.000000     1.000000  ...
#
#               D942         D943         D944         D945         D946  \
# count  3751.000000  3751.000000  3751.000000  3751.000000  3751.000000
# mean      0.005972     0.003566     0.002522     0.003599     0.001706
# std       0.052931     0.041530     0.028999     0.044159     0.026279
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#               D947         D948         D949         D950         D951
# count  3751.000000  3751.000000  3751.000000  3751.000000  3751.000000
# mean      0.073312     0.003718     0.144028     0.092621     0.147179
# std       0.089265     0.035645     0.099207     0.077216     0.099669
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.025600     0.000000     0.125000     0.035700     0.088900
# 50%       0.051300     0.000000     0.125000     0.071400     0.133333
# 75%       0.102564     0.000000     0.125000     0.107143     0.177778
# max       1.000000     0.916667     0.875000     1.000000     0.955556
#
# [8 rows x 941 columns]

# %%
fig, ax_arr = plt.subplots(1, 2, figsize=(15,5))
rdm = np.random.choice(non_binaries,size=3)

train[rdm[0]].plot(kind='hist', ax=ax_arr[0])
train[rdm[1]].plot(kind='hist', ax=ax_arr[1])
plt.show()

# %% [markdown]
# On remarque que les données sont pour la plupart en skew et du coup on pourrait avoir une très grande quantité d'outliers. De plus, cette sparsité des données implique une très mauvaise séparation en train et test, surtout en random.

# %%
fig, ax_arr = plt.subplots(1, 2, figsize=(15,5))
train[rdm[0]].plot(kind='box', ax=ax_arr[0])
train[rdm[1]].plot(kind='box', ax=ax_arr[1])
plt.show()

# %% [markdown]
# On note qu'il ya beaucoup de outliers <br>
# Toutefois, compte tenu du très peu de nombre lignes que nous avons, il ne serait pas judicieux de les supprimer pour le moment.

# %% [markdown]
# Search for correlation

# %%
cor = train.corr()

# %%
def get_correlated_features(cor:pd.DataFrame,threshold:float):
    """
    Return correlated features over a given Threshold
    cor : pearson correlation dataframe
    threshold : correlation Threshold 
    """
    #get max correlated columns index
    Argmax = cor[cor!=1].replace(np.nan,0).apply(lambda x: np.argmax(np.abs(x)))
    #get the argmax correlation value 
    Cor = [cor.iloc[i:i+1,Argmax[i]:Argmax[i]+1].values[0][0] for i in range(len(Argmax))]
    #get the argmax colname
    Col = [cor.columns[Argmax[i]] for i in range(len(Argmax))]
    
    max_cor = pd.DataFrame({'Argmax':Argmax, 'Cor':Cor, 'Col':Col}).sort_values('Cor')
    max_cor.reset_index(inplace=True)
    too_correlated = max_cor[(max_cor.Cor>=threshold)|(max_cor.Cor<=-threshold)].drop_duplicates('Cor')
    #     too_correlated = max_cor[(max_cor.Cor>=np.abs(threshold))].drop_duplicates('Cor')
    
    return too_correlated


def drop_too_correlated(too_correlated, cols):
    temp = [too_correlated["index"].values[i] for i in range(len(too_correlated)) if ((too_correlated["index"].values[i] in cols) and (too_correlated.Col.values[i] in cols)) ]
    return [col for col in cols if not col in temp]

# %%
too_correlated = get_correlated_features(cor,0.8)
too_correlated.head(5)
# Out:
#   index  Argmax       Cor   Col
# 0  D183     857 -0.895145  D857
# 1    D6      10 -0.882761   D10
# 3   D26      25 -0.864075   D25
# 5  D222     932 -0.860354  D932
# 7   D86      91 -0.854899   D91

# %%
from sklearn.feature_selection import mutual_info_classif, SelectFromModel,SelectKBest,chi2

# %%
def get_Mutual_Info_With_Y(X:pd.DataFrame,Y:pd.Series,threshold:float):
    """
    Return Mutual_Info_ of X's features With_Y over a given threshold
    X : features dataframe
    Y : target
    threshold : Mutual Info Threshold 
    """
    ft_selec = mutual_info_classif(X, Y , discrete_features='auto', n_neighbors=3 ,random_state=42)
    mi = pd.DataFrame({'Col':X.columns,'Mutual_Info_With_Y':ft_selec})
    mi = mi[mi.Mutual_Info_With_Y>=threshold].sort_values("Mutual_Info_With_Y",ascending=False)
    return mi

def get_chi2_best_features(X:pd.DataFrame,Y,n:int):
    """
    Return n best features based on chi2 score
    X : features dataframe
    Y : target
    n : number of features 
    """
#     X_norm = MinMaxScaler().fit_transform(X)
    selector = SelectKBest(chi2, k=n).fit(X, Y)
    mask = selector.get_support()
    return X.columns[mask].tolist()

def get_best_features_tree_based_model(model,X:pd.DataFrame,Y:pd.Series,n:int):
    """
    Return n best features based on model score
    model : model 
    X : features dataframe
    Y : target
    n : number of features 
    """
    embeded_selector = SelectFromModel(model, max_features=n)
    embeded_selector.fit(X, Y)
    mask = embeded_selector.get_support()
    return X.columns[mask].tolist()

# %%
mi_features = get_Mutual_Info_With_Y(X,Y,0.05)['Col'].tolist()
best_chi2_features = get_chi2_best_features(X,Y,200)

rf = RandomForestClassifier()
rf_best = get_best_features_tree_based_model(rf,X,Y,200)

best_inter = list(set(mi_features)&set(best_chi2_features)&set(rf_best))
best_union = list(set(mi_features+best_chi2_features+rf_best))

# %%
best_inter
# Out:
# ['D64', 'D61', 'D27']

# %% [markdown]
# En se basant sur la corrélation chi2 et le mutual information, on conclut que les colonnes D64, D27 et D61 sont celles qui sont les plus corrélée à la variable activity.

# %%
ls = ['Activity']+best_inter+np.random.choice(best_union,size=2).tolist()
sns.pairplot(train[ls], hue ='Activity', kind='scatter')
plt.show()

# %% [markdown]
# On peut noter que les trois varibales les plus corrélées à la variables dépendantes ne permettent pas forcément de faire une nette séparation entre les deux classes. Mais au sein des classes, on peut noter une distribution des variables explicatives qui peut potentiellement servir de séparation.

# %%
sns.countplot(train.D27)
plt.show()

# %%
train.D64.plot()
plt.show()

# %%
train.D61.plot()
plt.show()

# %% [markdown]
# ## ACP

# %%
train_embedded = PCA(100, random_state=42).fit_transform(X)
plt.scatter(train_embedded[:,0],train_embedded[:,1],c=train.Activity.values)
plt.xlabel('dim1')
plt.ylabel('dim2')
plt.show()

# %%
#acp sur les colonnes binaires uniquement
train_embedded = PCA(100,random_state=42).fit_transform(X[binaries])
plt.scatter(train_embedded[:,0],train_embedded[:,1],c=train.Activity.values)
plt.show()

# %%
#acp sur les colonnes non binaires uniquement
train_embedded = PCA(100,random_state=42).fit_transform(X[non_binaries])
plt.scatter(train_embedded[:,0],train_embedded[:,1],c=train.Activity.values)
plt.show()

# %% [markdown]
# L'acp ne permet pas de faire la séparation des classes certainement dû à l'hypoyhèse de linéarité, d'autant plus que nous avons beaucoup de colonnes one-hot encodées. <br>
# Lorsqu'on utilise uniquement les colonnes non-bianiares on remarque que le jeu de données n'est pas séparable, ou du mois, moins bien qu'avec la totalité des données. <br>
# On peut conclure que les colonnes non binaires seules ne suffisent pas pour expliquer les classes.

# %%
def get_eigv_df(X:pd.DataFrame,dim:int):

    """
    plot the explained variance given the number of dimension of the PCA
    X_train : X DataFrame to reduce
    dim : number of dimension for the PCA
    """

    pca = PCA(dim).fit(X)

    eigv_df = pd.DataFrame({'dimension' : ['dim' + str(x+1) for x in range(dim)],
        'explained_var': pca.explained_variance_,
        '%_explained_var': np.round(pca.explained_variance_ratio_*100),
        '%_cumulative_explained_var': np.round(np.cumsum(pca.explained_variance_ratio_)*100)
        })
        
    fig, (ax1,ax2) = plt.subplots(1,2, figsize = (20,5))
    ax1.bar(eigv_df.dimension, eigv_df['%_explained_var'])
    ax1.set_title('Explained var'+str(dim))
    ax1.get_xaxis().set_visible(False)
    
    ax2.bar(eigv_df.dimension, eigv_df['%_cumulative_explained_var'])
    ax2.set_title('Cumu Explained var'+str(dim))
    m = max(eigv_df['%_cumulative_explained_var'])
    ax2.axhline(y = m, linewidth=0.5, color='red',linestyle='--')
    ax2.get_xaxis().set_visible(False)
    plt.text(dim,m+1,str(m)+'%')
    plt.show()

# %%
get_eigv_df(X,100)

# %%
get_eigv_df(X,200)

# %%
get_eigv_df(X,300)

# %%
get_eigv_df(X,30)

# %% [markdown]
# On constate qu'une ACP avec 300 dimensions permet de récuppérer 93% de l'information du jeu de données mais avec 270 dimensions non significatives. Ces dimensions pourrait s'apparenter à du bruit. Par contre les 30 premières dimensions sont les plus significatives mais ne conservent que la moitié de l'information contenue dans le dataset. Idéalement, nous optons pour une rédutioon à 100 dimesnions en conservant 75% de l'information pour commencer (étant données qu'on à pas d'information précise la perte d'information acceptable sur le jeu de données)

# %% [markdown]
# ## T-SNE

# %%
X_embedded = TSNE(n_components=2,perplexity=30, n_iter=400).fit_transform(X)
X_embedded.shape
# Out:
# (3751, 2)

# %%
plt.scatter(X_embedded[:,0], X_embedded[:,1],c=Y.values)
plt.show()

# %% [markdown]
# On note également qu'une réduction TSNE ne permet pas de séparer convebalemnt le jeu de donnée.

# %% [markdown]
# #Pas une bonne idée de prendre les données PCA et t-sne pour la prédiction <br> Nous allons utiliser l'ensemble des données.

# %% [markdown]
# ## Modélisation

# %% [markdown]
# #### Usefull function

# %%
def valid_model(model,X,Y):
    """
    validate model with crossvalidation
    X : features 
    Y : labels
    model : classifier
    """
    cv_loss_array = []
    kf = StratifiedKFold(n_splits=5,random_state=42, shuffle=True)
    for train_index, test_index in kf.split(X,Y):
        if type(X) == pd.DataFrame:
            X_train, X_valid = X.values[train_index], X.values[test_index]
            y_train, y_valid = Y.values[train_index], Y.values[test_index]
        else:
            X_train, X_valid = X[train_index], X[test_index]
            y_train, y_valid = Y[train_index], Y[test_index]
            
        model.fit(X,Y)
        probas_train = model.predict_proba(X_valid)[:,1]                 
        cv_loss_array.append(log_loss(y_valid,probas_train))        
    return np.mean(cv_loss_array)

def train_pred(X,Y,clf, acp:list):
    """
    train and test a classifier with or whithout PCA
    X : features 
    Y : labels
    clf : classifier
    acp : PCA number of dimension
    """
    mean_loss = valid_model(clf,X,Y)
    print('Mean CV loss:',mean_loss)

    for dim in acp:
        
        if dim>0 and dim<X.shape[1]:
            print('\n')
            print(f'---ACP {dim} dimensions---'*4)
            X_PCA = PCA(dim, random_state=42).fit_transform(X)
            mean_loss = valid_model(clf,X_PCA,Y)
            print('Mean CV loss:',mean_loss)
            

def train_test_grid(X,Y,clf, parameters:dict):
    """
    train and test on grid with crossvalidation
    X : features 
    Y : labels
    clf : classifier
    parameters : grid dict
    """
    grid = GridSearchCV(clf, parameters, cv=5)
    grid.fit(X, Y)

    print('Best estimator :',grid.best_estimator_)
    mean_loss = valid_model(grid.best_estimator_,X,Y)
    print('Mean CV loss:',mean_loss)
    
#     probas_train = grid.best_estimator_.predict_proba(X_train)[:,1]
#     print('Train loss:',log_loss(y_train,probas_train))
#     probas = grid.best_estimator_.predict_proba(X_test)[:,1]
#     print('Test loss:',log_loss(y_test,probas))

    return grid


def make_submission(model, test, sub_name:str):
    """
    write the submission df
    model : the final model
    test : the test df for the final prediction
    subname : name of the submission file
    """
    probas = model.predict_proba(test)[:,1]
    submission = pd.DataFrame({'MoleculeId':[x for x in range(1,len(test)+1)],'PredictedProbability':probas})
    submission.to_csv(f'submission_{sub_name}.csv',index=False)

# %% [markdown]
# #### Logistic reg baseline

# %% [markdown]
# ##### #Logreg all dataset

# %%
clf = LogisticRegression(random_state=42, solver='saga', C=0.1, l1_ratio=0.6, penalty='elasticnet')
train_pred(X,Y, clf, acp=[100,300])
# Out:
# Mean CV loss: 0.4557560602199674
#
#
# ---ACP 100 dimensions------ACP 100 dimensions------ACP 100 dimensions------ACP 100 dimensions---
# Mean CV loss: 0.49106788182086936
#
#
# ---ACP 300 dimensions------ACP 300 dimensions------ACP 300 dimensions------ACP 300 dimensions---
# Mean CV loss: 0.46211043372364263

# %% [markdown]
# Il semble que l'acp n'améliore pas les perf du model.

# %%
coefs = []
CV_loss_array = []
kf = StratifiedKFold(n_splits=5,random_state=42, shuffle=True)
for train_index, test_index in kf.split(X,Y):
    X_train, X_valid = X.values[train_index], X.values[test_index]
    y_train, y_valid = Y.values[train_index], Y.values[test_index]
    
    clf.fit(X_train,y_train)
    coefs.append(clf.coef_)

model_feats = np.mean(coefs,axis=0)
feat = pd.DataFrame({'col':X.columns,'coef':model_feats[0]})
lasso_cols = feat[feat.coef!=0].col
print('Nombre de features selectionnés par la régression logistique:', len(lasso_cols))
# Out:
# Nombre de features selectionnés par la régression logistique: 329

# %% [markdown]
# ##### #On selected feats

# %%
#drop too correlated from lasso cols
temp = drop_too_correlated(too_correlated,lasso_cols)
train_pred(X[temp],Y, clf, acp=[100,200])
# Out:
# Mean CV loss: 0.455740308469229
#
#
# ---ACP 100 dimensions------ACP 100 dimensions------ACP 100 dimensions------ACP 100 dimensions---
# Mean CV loss: 0.48386827175428715
#
#
# ---ACP 200 dimensions------ACP 200 dimensions------ACP 200 dimensions------ACP 200 dimensions---
# Mean CV loss: 0.4623957303990598

# %%
#try scaling data before training 
scaled = MinMaxScaler().fit_transform(X[lasso_cols])
train_pred(scaled,Y, clf, acp=[100,300])
# Out:
# Mean CV loss: 0.4551734410598959
#
#
# ---ACP 100 dimensions------ACP 100 dimensions------ACP 100 dimensions------ACP 100 dimensions---
# Mean CV loss: 0.48298073367611066
#
#
# ---ACP 300 dimensions------ACP 300 dimensions------ACP 300 dimensions------ACP 300 dimensions---
# Mean CV loss: 0.45630897719050445

# %%
#Model base line avec données binaires uniquement
train_pred(X[binaries],Y, clf, acp=[100,300])
# Out:
# Mean CV loss: 0.4653312447694843
#
#
# ---ACP 100 dimensions------ACP 100 dimensions------ACP 100 dimensions------ACP 100 dimensions---
# Mean CV loss: 0.5043914878107569
#
#
# ---ACP 300 dimensions------ACP 300 dimensions------ACP 300 dimensions------ACP 300 dimensions---
# Mean CV loss: 0.4706990186146486

# %%
#Model base line avec données non binaires uniquement
train_pred(X[non_binaries],Y, clf, acp=[100,300])
# Out:
# Mean CV loss: 0.549975192478375
#
#
# ---ACP 100 dimensions------ACP 100 dimensions------ACP 100 dimensions------ACP 100 dimensions---
# Mean CV loss: 0.5419051707728926
#
#
# ---ACP 300 dimensions------ACP 300 dimensions------ACP 300 dimensions------ACP 300 dimensions---
# Mean CV loss: 0.5412696308202205

# %% [markdown]
# Lorqu'on utilise les variables binnaires uniquement on constate à peu près les mêmes perf que le modèle avec toutes les variables, il y a aussi le même constat sur l'ACP. Par contre, le modèle baseline entrainé avec les données non binaires n'apprends pas assez.

# %% [markdown]
# ##### #Rugalization on Logreg

# %%
clf = LogisticRegression(solver ='saga', C=0.1, random_state=42)

parameters = {  
    'penalty' : ['l1','elasticnet'],
    'l1_ratio': [0.6,0.8,0.9,1]}

grid = train_test_grid(X,Y,clf, parameters)
# Out:
# Best estimator : LogisticRegression(C=0.1, l1_ratio=0.6, penalty='elasticnet', random_state=42,
#                    solver='saga')
# Mean CV loss: 0.4557560602199674

# %%
make_submission(grid, test, 'logreg_reg')

# %% [markdown]
# <span style="color:blue">Score public **0.52896**</span>
# <br>
# <span style="color:blue">Score privé **0.47406**</span>

# %% [markdown]
# #### Random Forest

# %% [markdown]
# ##### #Scratch

# %%
rf_clf = RandomForestClassifier(n_estimators=200,criterion='gini',max_depth=6, random_state=42)

# %%
train_pred(X,Y, rf_clf, acp=[200])
# Out:
# Mean CV loss: 0.4871983347640878
#
#
# ---ACP 200 dimensions------ACP 200 dimensions------ACP 200 dimensions------ACP 200 dimensions---
# Mean CV loss: 0.4993152213377118

# %% [markdown]
# Feature selection

# %%
model = rf_clf.fit(X,Y)
forest_importances = pd.DataFrame({'Importance':rf_clf.feature_importances_, 'Col':X.columns})
best_rf = forest_importances[forest_importances.Importance>0.001].sort_values('Importance', ascending=False)

# %%
train_pred(X[best_rf.Col.values],Y, rf_clf, acp=[0])
# Out:
# Mean CV loss: 0.4542389060756493

# %%
temp = drop_too_correlated(too_correlated,best_rf.Col.values)
train_pred(X[temp],Y, rf_clf, acp=[0])
# Out:
# Mean CV loss: 0.4573813468610556

# %%
train_pred(X[lasso_cols],Y, rf_clf, acp=[0])
# Out:
# Mean CV loss: 0.49142644644535355

# %% [markdown]
# nobinaries features

# %%
train_pred(X[non_binaries],Y ,rf_clf, acp=[0])
# Out:
# Mean CV loss: 0.49161101295076176

# %% [markdown]
# binaries features

# %%
train_pred(X[binaries],Y ,rf_clf, acp=[0])
# Out:
# Mean CV loss: 0.5381598600250963

# %% [markdown]
# Le random forest n'a pas de performances très bonnes. Ce modèle performe mieux sur les colonnes séléectionnées avec la feature importance que sur les colonnes selectionnées par la regression logistique.

# %% [markdown]
# ##### #Random forest Grid

# %%
rf_class = RandomForestClassifier(random_state=42,n_jobs=-1)

parameters = { 'n_estimators' : [200,300,400,500],
               'max_depth' : [4,6,8],
               'min_samples_leaf' : [1,2],
               'criterion' : ['entropy','gini'] }

grid = train_test_grid(X[best_rf.Col.values],Y,rf_class, parameters)
# Out:
# Best estimator : RandomForestClassifier(max_depth=8, min_samples_leaf=2, n_estimators=500,
#                        n_jobs=-1, random_state=42)
# Mean CV loss: 0.37337986763367514

# %%
make_submission(grid, test[best_rf.Col.values], 'rf_reg')

# %% [markdown]
# <span style="color:blue">Score public **0.48124**</span>
# <br>
# <span style="color:blue">Score privé **0.45308**</span>

# %% [markdown]
# #### XGBoost

# %%
xgb_clf = XGBClassifier(n_estimators = 200, max_depth = 4, learning_rate=.1)
train_pred(X,Y, xgb_clf, acp=[0])
# Out:
# [23:57:29] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:57:36] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:57:43] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:57:50] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:57:57] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Mean CV loss: 0.20801174435014436

# %% [markdown]
# Avec l'ACP On a de meilleur résultat sur le train. Mais on est certainement en sur apprentissage. Il faut essyaer un feature selction

# %% [markdown]
# Feature selection

# %%
# model = xgb_clf.fit(X,Y)
forest_importances = pd.DataFrame({'Importance':xgb_clf.feature_importances_, 'Col':X.columns})
best_xgb = forest_importances[forest_importances.Importance>0.001].sort_values('Importance', ascending=False)
train_pred(X[best_xgb.Col.values], Y, xgb_clf, acp=[0])
# Out:
# [23:58:03] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:58:06] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:58:08] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:58:10] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:58:13] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Mean CV loss: 0.2035796181232762

# %%
temp = drop_too_correlated(too_correlated,best_xgb.Col.values)
train_pred(X[temp],Y, xgb_clf, acp=[0])
# Out:
# [23:58:15] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:58:17] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:58:19] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:58:21] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:58:23] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Mean CV loss: 0.2153928260659191

# %%
train_pred(X[lasso_cols],Y, xgb_clf, acp=[0])
# Out:
# [23:58:25] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:58:26] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:58:28] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:58:29] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:58:31] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Mean CV loss: 0.25708559327181835

# %% [markdown]
#  **essayer de regulariser le xgb a 500 ou 300 dimensions sur mes features impoetances**

# %% [markdown]
# ##### #XGB Grid

# %%
xgb = XGBClassifier(n_estimators=200, max_depth=4, learning_rate= 0.1,eval_metric = log_loss,n_jobs=-1)

parameters = {  'reg_alpha' : [2,3,4], #[1.1,1.5,2,3]
                'reg_lambda' : [2,3,4],
                'gamma': [0.001,0.01]}

grid_xgb = train_test_grid(X,Y,xgb, parameters)
# Out:
# [23:58:32] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:58:38] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:58:44] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:58:49] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:58:55] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:59:00] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:59:06] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:59:12] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:59:17] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:59:23] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:59:28] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:59:34] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:59:39] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:59:45] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:59:50] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:59:56] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:00:01] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:00:07] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:00:12] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:00:18] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:00:23] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:00:29] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:00:35] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:00:41] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:00:46] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:00:52] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:00:57] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:01:03] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:01:08] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:01:14] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:01:19] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:01:25] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:01:30] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:01:36] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:01:41] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:01:47] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:01:52] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:01:57] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:02:03] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:02:08] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:02:14] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:02:19] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:02:25] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:02:30] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:02:36] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:02:41] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:02:46] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:02:52] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:02:57] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:03:03] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:03:08] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:03:14] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:03:19] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:03:25] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:03:31] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:03:36] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:03:42] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:03:47] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:03:53] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:03:59] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:04:04] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:04:10] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:04:15] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:04:21] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:04:27] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:04:32] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:04:38] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:04:43] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:04:49] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:04:54] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:05:00] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:05:05] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:05:10] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:05:16] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:05:22] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:05:27] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:05:33] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:05:39] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:05:44] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:05:49] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:05:55] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:06:01] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:06:06] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:06:12] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:06:17] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:06:23] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:06:29] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:06:34] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:06:40] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:06:45] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:06:51] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Best estimator : XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               eval_metric=<function log_loss at 0x000002B7C3139550>,
#               gamma=0.001, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#               max_depth=4, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=200, n_jobs=-1,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=2, reg_lambda=3, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)
# [00:06:58] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:07:05] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:07:11] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:07:18] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:07:24] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Mean CV loss: 0.21199656473592307

# %%
grid_xgb.best_estimator_
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               eval_metric=<function log_loss at 0x000002B7C3139550>,
#               gamma=0.001, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#               max_depth=4, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=200, n_jobs=-1,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=2, reg_lambda=3, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
# grid_best_xgb = XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1,
#               eval_metric= log_loss, gamma=0.001,
#               gpu_id=-1, importance_type='gain', interaction_constraints='',
#               learning_rate=0.1, max_delta_step=0, max_depth=4,
#               min_child_weight=1, monotone_constraints='()',
#               n_estimators=200, n_jobs=-1, num_parallel_tree=1,
#               objective='binary:logistic', random_state=0, reg_alpha=2,
#               reg_lambda=3, scale_pos_weight=1, subsample=1,
#               tree_method='exact', use_label_encoder=True,
#               validate_parameters=1, verbosity=None)

forest_importances = pd.DataFrame({'Importance': grid_xgb.best_estimator_.feature_importances_, 'Col':X.columns})
best_grid_xgb = forest_importances[forest_importances.Importance>0.001].sort_values('Importance', ascending=False)
train_pred(X[best_grid_xgb.Col.values], Y, grid_xgb.best_estimator_, acp=[0])
# Out:
# [00:08:53] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:08:55] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:08:57] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:09:00] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:09:02] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Mean CV loss: 0.21585974074148115

# %%
xgb_importance(xgb_clf,importance_type='gain',max_num_features=25)
plt.show()

# %%
temp = drop_too_correlated(too_correlated,best_grid_xgb.Col.values)
train_pred(X[temp],Y, grid_xgb.best_estimator_, acp=[0])
# Out:
# [00:09:05] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:09:07] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:09:09] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:09:11] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:09:13] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Mean CV loss: 0.22493881723624595

# %%
make_submission(grid_xgb.best_estimator_, test[temp], 'grid_xgb_best')

# %% [markdown]
# <span style="color:blue">Score public **0.42424**</span>
# <br>
# <span style="color:blue">Score privé **0.39217**</span>

# %% [markdown]
# #### LGBM

# %%
lgb = LGBMClassifier(random_state=42, subsample_freq = 20, subsample = 0.9, 
                       reg_lambda = 1.2, reg_alpha = 1.1,num_leaves= 200, n_estimators = 700, 
                       min_split_gain =  0.4, max_depth =  15, colsample_bytree = 0.8)

# %%
# lgb = LGBMClassifier(random_state=314, silent=True,subsample_freq = 20, subsample = 0.9, learning_rate=0.01,
#                        reg_lambda = 1.2, reg_alpha = 3, num_leaves= 200, n_estimators = 700, 
#                        min_split_gain =  0.1, max_depth =  15, colsample_bytree = 0.8,importance_type ='gain')

train_pred(X, Y, lgb, acp=[0])
# Out:
# Mean CV loss: 0.14105665617342406

# %%
make_submission(lgb, test, 'lgb_all_simple')

# %% [markdown]
# <span style="color:blue">Score public **0.42922**</span>
# <br>
# <span style="color:blue">Score privé **0.39429**</span>

# %%
forest_importances = pd.DataFrame({'Importance':lgb.feature_importances_, 'Col':X.columns})
# forest_importances.sort_values('Importance', ascending=False).head(10)
best_lgb = forest_importances[forest_importances.Importance>=50].sort_values('Importance', ascending=False)
train_pred(X[best_lgb.Col.values], Y, lgb, acp=[0])
make_submission(lgb, test[best_lgb.Col.values], 'lgb_on_best_feats')
# Out:
# Mean CV loss: 0.18451368527650708

# %% [markdown]
# <span style="color:blue">Score public **0.45717**</span>
# <br>
# <span style="color:blue">Score privé **0.48831**</span>

# %%
temp = drop_too_correlated(too_correlated,X.columns)
train_pred(X[temp], Y, lgb, acp=[0])
make_submission(lgb, test[temp], 'lgb_on_temp')
# Out:
# Mean CV loss: 0.14279096690411636

# %% [markdown]
# <span style="color:blue">Score public **0.42497**</span>
# <br>
# <span style="color:blue">Score privé **0.39319**</span>

# %%
lgb_importance(lgb,importance_type='gain',max_num_features=150,figsize=(10,30))
plt.show()

# %%
lgb = LGBMClassifier(random_state=314,subsample_freq = 20, subsample = 0.9, 
                        num_leaves= 200, n_estimators = 700, importance_type ='gain',
                       min_split_gain =  0.4, max_depth =  15, colsample_bytree = 0.8)

parameters = {  'learning_rate':  [0.01,0.05,0.1],
                'reg_alpha' : [2,3,4,6],
                'reg_lambda' : [2,3,4,6]}

grid_lgb = train_test_grid(X,Y ,lgb, parameters)
# Out:
# Best estimator : LGBMClassifier(colsample_bytree=0.8, importance_type='gain', learning_rate=0.01,
#                max_depth=15, min_split_gain=0.4, n_estimators=700,
#                num_leaves=200, random_state=314, reg_alpha=2, reg_lambda=3,
#                subsample=0.9, subsample_freq=20)
# Mean CV loss: 0.21038979208022277

# %%
make_submission(grid_lgb.best_estimator_, test, 'lgb_grid_all')

# %% [markdown]
# <span style="color:blue">Score public **0.42593**</span>
# <br>
# <span style="color:blue">Score privé **0.38348**</span>

# %%
temp_lgb = LGBMClassifier(random_state=32,subsample_freq = 20, subsample = 0.9, learning_rate=0.05,
                        num_leaves= 200, n_estimators = 700, importance_type ='gain',
                       min_split_gain =  0.4, max_depth =  15, colsample_bytree = 0.8)


train_pred(X[non_binaries], Y, temp_lgb, acp=[0])

make_submission(temp_lgb, test[non_binaries], 'lgb_on_temp')
# Out:
# Mean CV loss: 0.07523908235416711

# %%
temp_lgb = LGBMClassifier(random_state=32,subsample_freq = 20, subsample = 0.9, learning_rate=0.05,
                        num_leaves= 200, n_estimators = 300, importance_type ='gain',
                       min_split_gain =  0.4, max_depth =  10, colsample_bytree = 0.8)
                          
train_pred(X[non_binaries], Y, temp_lgb, acp=[0])
print('Score public **0.41365**')
print('Score privé **0.39401**')
# Out:
# Mean CV loss: 0.0838707339316827
# Score public **0.41365**
# Score privé **0.39401**

# %%
temp_X = pd.concat([X[non_binaries],X[binaries].mean(axis=1)],axis=1)
temp_test = pd.concat([test[non_binaries],test[binaries].mean(axis=1)],axis=1)

train_pred(temp_X, Y, temp_lgb, acp=[0])
print('Score public **0.42151**')
print('Score privé **0.39352**')
# Out:
# Mean CV loss: 0.08456768698901604
# Score public **0.42151**
# Score privé **0.39352**

# %%
temp_lgb = LGBMClassifier(random_state=32,subsample_freq = 20, subsample = 0.9, learning_rate=0.05,
                        num_leaves= 200, n_estimators = 300, importance_type ='gain',
                       min_split_gain =  0.4, max_depth = 10  , colsample_bytree = 0.8)

train_pred(X[non_binaries], Y, temp_lgb, acp=[0])

print('Score public **0.40944**')
print('Score privé **0.39283**')
# Out:
# Mean CV loss: 0.0838707339316827
# Score public **0.40944**
# Score privé **0.39283**

# %%
# temp_lgb = LGBMClassifier(random_state=32, learning_rate=0.1, n_estimators =50, max_depth=6,num_leaves= 200)

# 
# max_depth = 10  ,
# colsample_bytree = 0.8
# num_leaves= 200
# subsample_freq = 20, subsample = 0.9, learning_rate=0.05,   min_split_gain = 0.4,

# train_pred(X[non_binaries], Y, temp_lgb, acp=[0])

# make_submission(temp_lgb, test[non_binaries], 'lgb_on_temp')
